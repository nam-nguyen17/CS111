# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv')
df.drop(['day', 'month', 'year', 'countryterritoryCode', 'popData2019', 
         'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000'], axis=1, inplace=True)
df
# Out:
#           dateRep  cases  deaths countriesAndTerritories geoId continentExp
# 0      25/11/2020    185      13             Afghanistan    AF         Asia
# 1      24/11/2020    246      17             Afghanistan    AF         Asia
# 2      23/11/2020    252       8             Afghanistan    AF         Asia
# 3      22/11/2020    154      12             Afghanistan    AF         Asia
# 4      21/11/2020    232      25             Afghanistan    AF         Asia
# ...           ...    ...     ...                     ...   ...          ...
# 57848  25/03/2020      0       0                Zimbabwe    ZW       Africa
# 57849  24/03/2020      0       1                Zimbabwe    ZW       Africa
# 57850  23/03/2020      0       0                Zimbabwe    ZW       Africa
# 57851  22/03/2020      1       0                Zimbabwe    ZW       Africa
# 57852  21/03/2020      1       0                Zimbabwe    ZW       Africa
#
# [57853 rows x 6 columns]

# %%
df1 = df[['cases', 'continentExp']].groupby('continentExp').sum()
df1.sort_values(by=['cases'], inplace=True, ascending=False)
df1
# Out:
#                  cases
# continentExp
# America       25618851
# Europe        16888461
# Asia          15228482
# Africa         2093055
# Oceania          50332
# Other              696

# %%
df1.plot.pie(y='cases',figsize=(10, 20), autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='cases'>

# %%
dfx = df.groupby('continentExp').agg(['max', 'min', 'mean'])
dfx
# Out:
#                cases                    deaths
#                  max   min         mean    max   min       mean
# continentExp
# Africa         13944  -209   150.190514    572     0   3.611151
# America       196117 -8261  1999.754196   4928     0  55.480290
# Asia           97894  -110  1223.859359   2003  -443  21.269710
# Europe         86852 -1385  1034.388498   2004 -1918  23.471121
# Oceania         1384     0    22.153169     59     0   0.492958
# Other            134    -9    10.875000      2     0   0.109375
