# %%
import numpy as np
import pandas as pd

# %%
#from dict
s1 = pd.Series({'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5})
print(s1)
type(s1)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64
# pandas.core.series.Series

# %%
#from list
s2 = pd.Series([2,4,5,7,2], index=['a', 'b', 'c', 'd', 'e'])
s2
# Out:
# a    2
# b    4
# c    5
# d    7
# e    2
# dtype: int64

# %%
s3 = pd.Series(15, index=['a', 'b', 'c', 'd', 'e'])
s3
# Out:
# a    15
# b    15
# c    15
# d    15
# e    15
# dtype: int64

# %%
s2[:'c']
# Out:
# a    2
# b    4
# c    5
# dtype: int64

# %%
s2[['a', 'b', 'e']]
# Out:
# a    2
# b    4
# e    2
# dtype: int64

# %%
s2[s2>2]
# Out:
# b    4
# c    5
# d    7
# dtype: int64

# %%
s2[s2>=s2.mean()]
# Out:
# b    4
# c    5
# d    7
# dtype: int64

# %%
s2.head()
# Out:
# a    2
# b    4
# c    5
# d    7
# e    2
# dtype: int64

# %%
s2.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
s2['f'] = 100
s2
# Out:
# a      2
# b      4
# c      5
# d      7
# e      2
# f    100
# dtype: int64

# %%
s2 * 2
# Out:
# a      4
# b      8
# c     10
# d     14
# e      4
# f    200
# dtype: int64

# %%
s4 = s2[:'d']
s5 = s2['b':]
print(s4)
print(s5)
# Out:
# a    2
# b    4
# c    5
# d    7
# dtype: int64
# b      4
# c      5
# d      7
# e      2
# f    100
# dtype: int64

# %%
s6 = s4 + s5
s6
# Out:
# a     NaN
# b     8.0
# c    10.0
# d    14.0
# e     NaN
# f     NaN
# dtype: float64

# %%
s6.ffill()
# Out:
# a     NaN
# b     8.0
# c    10.0
# d    14.0
# e    14.0
# f    14.0
# dtype: float64

# %%
s6.dropna(inplace=True)

# %%
s6
# Out:
# b     8.0
# c    10.0
# d    14.0
# dtype: float64

# %%
s1.describe()
# Out:
# count    5.000000
# mean     3.000000
# std      1.581139
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      4.000000
# max      5.000000
# dtype: float64

# %%
s1.quantile(.2)
# Out:
# 1.8

# %%
s1.var()
# Out:
# 2.5

# %%
df1 = pd.DataFrame({'c1': s1, 'c2': s2})
df1
# Out:
#     c1   c2
# a  1.0    2
# b  2.0    4
# c  3.0    5
# d  4.0    7
# e  5.0    2
# f  NaN  100

# %%
df1.dropna()
# Out:
#     c1  c2
# a  1.0   2
# b  2.0   4
# c  3.0   5
# d  4.0   7
# e  5.0   2

# %%
df1.fillna(df1['c1'].mean())
# Out:
#     c1   c2
# a  1.0    2
# b  2.0    4
# c  3.0    5
# d  4.0    7
# e  5.0    2
# f  3.0  100

# %%
epl = pd.read_csv('epldata_final.csv')
epl.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264     3.0           Chile
# 1        4395        9.5   5.60%         167     2.0         Germany
# 2        1529        5.5   5.90%         134     2.0  Czech Republic
# 3        2393        7.5   1.50%         122     1.0         England
# 4         912        6.0   0.70%         121     2.0          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
epl.shape
# Out:
# (461, 17)

# %%
df1.loc['b']
# Out:
# c1    2.0
# c2    4.0
# Name: b, dtype: float64

# %%
df1.iloc[1]
# Out:
# c1    2.0
# c2    4.0
# Name: b, dtype: float64

# %%
epl[5:15]
# Out:
#                        name     club  age position  position_cat  \
# 5           Hector Bellerin  Arsenal   22       RB             3
# 6            Olivier Giroud  Arsenal   30       CF             1
# 7             Nacho Monreal  Arsenal   31       LB             3
# 8          Shkodran Mustafi  Arsenal   25       CB             3
# 9                Alex Iwobi  Arsenal   21       LW             1
# 10             Granit Xhaka  Arsenal   24       DM             2
# 11  Alex Oxlade-Chamberlain  Arsenal   23       RM             2
# 12            Jack Wilshere  Arsenal   25       CM             2
# 13             Aaron Ramsey  Arsenal   26       CM             2
# 14         Francis Coquelin  Arsenal   26       DM             2
#
#     market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 5           30.0        1675        6.0  13.70%         119     2.0
# 6           22.0        2230        8.5   2.50%         116     2.0
# ...

# %%
epl.iloc[4]
# Out:
# name            Laurent Koscielny
# club                      Arsenal
# age                            31
# position                       CB
# position_cat                    3
# market_value                   22
# page_views                    912
# fpl_value                       6
# fpl_sel                     0.70%
# fpl_points                    121
# region                          2
# nationality                France
# new_foreign                     0
# age_cat                         4
# club_id                         1
# big_club                        1
# new_signing                     0
# Name: 4, dtype: object

# %%
epl[(epl['club'] == 'Arsenal') & (epl.position == "GK")]
# Out:
#                  name     club  age position  position_cat  market_value  \
# 2           Petr Cech  Arsenal   35       GK             4           7.0
# 22  Emiliano Martinez  Arsenal   24       GK             4           1.0
# 23       David Ospina  Arsenal   28       GK             4           7.0
#
#     page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 2         1529        5.5   5.90%         134     2.0  Czech Republic
# 22         372        4.0   4.20%           8     3.0       Argentina
# 23         544        5.0   0.20%           2     3.0        Colombia
#
#     new_foreign  age_cat  club_id  big_club  new_signing
# 2             0        6        1         1            0
# 22            0        2        1         1            0
# 23            0        4        1         1            0

# %%
epl[(epl.market_value) == epl.market_value.max()]
# Out:
#             name               club  age position  position_cat  market_value  \
# 92   Eden Hazard            Chelsea   26       LW             1          75.0
# 263   Paul Pogba  Manchester+United   24       CM             2          75.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 92         4220       10.5   2.30%         224     2.0     Belgium
# 263        7435        8.0  19.50%         115     2.0      France
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 92             0        3        5         1            0
# 263            0        2       12         1            1

# %%
epl[(epl.nationality) == 'South Korea']
# Out:
#                name            club  age position  position_cat  market_value  \
# 127  Lee Chung-yong  Crystal+Palace   29       RW             1           1.5
# 361   Ki Sung-yueng         Swansea   28       DM             2           7.0
# 379   Son Heung-min       Tottenham   25       LW             1          30.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region  nationality  \
# 127         327        4.5   0.10%          24     4.0  South Korea
# 361         478        5.0   0.00%          41     4.0  South Korea
# 379        2185        8.0   1.60%         174     4.0  South Korea
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 127            0        4        6         0            0
# 361            0        4       16         0            0
# 379            0        3       17         1            0

# %%
epl.groupby('club').count()
# Out:
#                    name  age  position  position_cat  market_value  \
# club
# Arsenal              28   28        28            28            28
# Bournemouth          24   24        24            24            24
# Brighton+and+Hove    22   22        22            22            22
# Burnley              18   18        18            18            18
# Chelsea              20   20        20            20            20
# Crystal+Palace       21   21        21            21            21
# Everton              28   28        28            28            28
# Huddersfield         28   28        28            28            28
# Leicester+City       24   24        24            24            24
# Liverpool            27   27        27            27            27
# Manchester+City      20   20        20            20            20
# Manchester+United    25   25        25            25            25
# Newcastle+United     21   21        21            21            21
# ...

# %%
df2 = epl[['club', 'market_value', 'age']].groupby('club').sum()
df2.sort_values(by=['market_value'], inplace=True, ascending=False)
df2
# Out:
#                    market_value  age
# club
# Manchester+City          564.00  540
# Chelsea                  553.55  541
# Arsenal                  550.00  747
# Manchester+United        514.10  639
# Tottenham                460.00  513
# Liverpool                440.50  669
# Everton                  282.75  734
# Southampton              230.00  574
# Leicester+City           207.50  654
# West+Ham                 194.00  602
# Crystal+Palace           162.25  589
# Stoke+City               150.00  617
# Swansea                  139.00  675
# Watford                  124.00  673
# Bournemouth              117.50  645
# Newcastle+United         109.25  555
# West+Brom                101.25  536
# Burnley                   71.25  503
# Brighton+and+Hove         55.50  623
# Huddersfield              50.15  728

# %%
import matplotlib.pyplot as plt
df2.plot.barh()
plt.show()

# %%
df3 = epl[['nationality', 'name']].groupby('nationality').count()
df3.sort_values(by=['name'], inplace=True, ascending=False)
top5 = df3.head(10).plot.pie(y='name', figsize=(10, 20), autopct='%1.2f%%')
top5
# Out:
# <AxesSubplot:ylabel='name'>
